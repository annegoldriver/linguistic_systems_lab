# %% [markdown]
# <a href="https://colab.research.google.com/github/annegoldriver/linguistic_systems_lab/blob/main/2026_02_systems_log.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 02/01/2026
# * append method
# * for loop

# %%
from datetime import datetime

now = datetime.now()
timestamp = now.strftime("%m/%d/%Y")

header = 'New OS installed, OS Vertias version 2026'
footer = 'Installed successfully'

environment = ['Asset','Virus', 'Asset', 'Error', 'Asset']
portfolio = []

for item in environment:
  if item != 'Virus' and item !='Error':
    portfolio.append(item)

print(timestamp)
print(header)
print(portfolio)
print("-" * 5, footer)
# Out:
# 02/08/2026
# New OS installed, OS Vertias version 2026
# ['Asset', 'Asset', 'Asset']
# ----- Installed successfully

# %% [markdown]
# 2/2/2026
#
# Soverign OS New OS installed.
# Battery charged

# %%
from datetime import datetime

now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')

header = 'New OS Initiative'
footer = 'Battery charged'

print(timestamp)
print('-' * len(header))
print(header)
print('-' * len(header))

missions = ['Definition', 'Decision', 'Freedom', 'Independence', 'Sovereignty']

for mission in missions:
    # Check if the current mission is one of the early steps
    if mission in ['Definition', 'Decision']:
        print(f'{mission}: Path to Freedom')

    # Check if we have reached the final goal
    elif mission == 'Sovereignty':
        print('STATUS: Sovereign OS Active')

print('-' * len(footer))
print(footer)
print('-' * len(footer))
# Out:
# 02/08/2026
# -----------------
# New OS Initiative
# -----------------
# Definition: Path to Freedom
# Decision: Path to Freedom
# STATUS: Sovereign OS Active
# ---------------
# Battery charged
# ---------------

# %% [markdown]
# 2/3/2026
#
# Debugging
#
# * Old OS conflict with New Integrity OS
# * Virus infected
# * Delete corrupted files
# * Patching
#
# To be continue

# %%
from datetime import datetime

now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')

header = 'Debugging'
footer = 'To be continued'

print(timestamp)
print('-' * len(header))
print(header)
print('-' * len(header))

files = ['New OS', 'Virus', 'Corrrupted', 'Old OS']

for file in files:
    if file == 'New OS':
        print(f"{file:12} : [Installed]")
    else:
        print(f"{file:12} : [Deleted]")

print('-' * len(footer))
print(footer)
print('-' * len(footer))
# Out:
# 02/08/2026
# ---------
# Debugging
# ---------
# New OS       : [Installed]
# Virus        : [Deleted]
# Corrrupted   : [Deleted]
# Old OS       : [Deleted]
# ---------------
# To be continued
# ---------------

# %% [markdown]
# 2/4/2026
#
# **Review and Practice**
#
# * For Loop in item: if, else
# * from import timedate
# * List practice
# * UI : '=' * len(header)

# %%
import time
from datetime import datetime

# 1. Initialization
now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')

header = 'SYSTEM LEGALLY SYNCRONIZED'
footer = 'MILESTONE REACHED'

print(f'DATE: {timestamp}')
print('=' * len(header))
print(f'{header}')
print('=' * len(header))

# 2. The legal workflow
status = ['Documentation filed', 'Case received', 'Case processed', 'Case approved', 'License issued', 'Certification delivered', 'Case closed', 'License active']

for process in status:
    if process == 'License active':
        print(f'STATUS: {process:25} -> [SYSTEM VERIFIED]')
    else:
        print(f'STATUS: {process:25} -> [SYNCED]')

# 3. Final Milestone Display
print('=' * len(header))
print(f'{footer}')
print('=' * len(header))
# Out:
# DATE: 02/08/2026
# ...
# SYSTEM LEGALLY SYNCRONIZED
# ...
# STATUS: Documentation filed       -> [SYNCED]
# STATUS: Case received             -> [SYNCED]
# STATUS: Case processed            -> [SYNCED]
# STATUS: Case approved             -> [SYNCED]
# STATUS: License issued            -> [SYNCED]
# STATUS: Certification delivered   -> [SYNCED]
# STATUS: Case closed               -> [SYNCED]
# STATUS: License active            -> [SYSTEM VERIFIED]
# ...
# MILESTONE REACHED
# ...

# %% [markdown]
# **Education Cultural Logic**
#
# * The formal college education: For Loop
# * The vocational education: While Loop
# ---
# **Python Tips**
# * Function Call

# %%
import time
from datetime import datetime

# Setup Header
now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')
header = 'Education Cultural Logic'
footer = 'Warning: Infinite Loop Detected in Agency Logic'

print(f'DATE: {timestamp}')
print('\n' + '***' * len(header))
print(f'{header}')
print('***' * len(header))

# Education Cultural Logic - Feb 2026
def academic_journey_comparison():
    print('\n' + '--- The Formal college education "For Loop" System ---')
    # A For Loop: We know the steps (4 years/credits) and we iterate through them.
    years_in_college = ["Freshman", "Sophomore", "Junior", "Senior"]

    for year in years_in_college:
        print(f"Year: {year} - Completing credits, moving to the next stage.")
    print("Result: Degree Awarded (Iteration Complete).\n")

    print("--- The Vocational education 'While Loop' System ---")
    # A While Loop: Runs as long as a condition (Mastery/Duty) is NOT yet met.
    mastery_level = 0
    required_mastery = 100
    years_passed = 0

    # We keep going "while" we haven't reached the PhD level of mastery
    while mastery_level < required_mastery:
        years_passed += 1
        mastery_level += 25  # Gaining deep expertise each cycle
        print(f"Year {years_passed}: Practicing, researching, enduring (Mastery: {mastery_level}%)")
        time.sleep(0.5)

    print('Result: Mastery Achieved (Condition Finally Met).')


academic_journey_comparison()

print('\n' + '***' * len(header))
print(f'{footer}')
print('***' * len(header))


# Function Call: Call it once
academic_journey_comparison()

print('\n' + '--- INTERMISSION ---')

# Function Call: Call it again!
academic_journey_comparison()
# Out:
# DATE: 02/08/2026
#
# ************************************************************************
# Education Cultural Logic
# ************************************************************************
#
# --- The Formal college education "For Loop" System ---
# Year: Freshman - Completing credits, moving to the next stage.
# Year: Sophomore - Completing credits, moving to the next stage.
# Year: Junior - Completing credits, moving to the next stage.
# Year: Senior - Completing credits, moving to the next stage.
# Result: Degree Awarded (Iteration Complete).
#
# --- The Vocational education 'While Loop' System ---
# Year 1: Practicing, researching, enduring (Mastery: 25%)
# Year 2: Practicing, researching, enduring (Mastery: 50%)
# Year 3: Practicing, researching, enduring (Mastery: 75%)
# Year 4: Practicing, researching, enduring (Mastery: 100%)
# Result: Mastery Achieved (Condition Finally Met).
#
# ************************************************************************
# ...

# %%
import time
from datetime import datetime

# 1. System Initialization
now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')

header = "CLEANING CORRUPTED FILES"
footer = "SYSTEM UPDATED."

print(f"[{timestamp}] SYSTEM BOOT")
print('===' * len(footer))
print(f"{header}")
print('===' * len(footer))

# 2. Defining the "Mitigation" Log (Data Structures)
# A dictionary to track the transition from "Problem" to "Mitigation
mitigation_log = [
    {"system": "Linguistic", "event": "Consonants", "result": "Clarified"},
    {"system": "Cognitive", "event": "Cognition alignment", "result": "Programming & Natural Language Sync"},
    {"system": "Finance", "event": "Ticket recovery", "result": "Refund requested"},
    {"system": "Legal", "event": "Housing management", "result": "Ultimatum -> [in progress]"},
    {"system": "Academic", "event": "University network", "result": "Connection established -> [Active]"}
]

# 3. Executing the "Cleanup" and "Update"
for entry in mitigation_log:
    time.sleep(0.6) # The "Processing" rhythm
    print(f"CLEANING CORRUPTED... [ {entry['event']:18} ] -> SUCCESS")
    print(f"INSTALLING CLEAN CODE... [ {entry['result']} ]")
    print("-" * 50)

# 4. Final System Statement
time.sleep(1)
print(f"\nIntegrity OS: Sovereignty is in progress.")
print("Architect of Life.\n")
print('===' * len(footer))
print(f"{footer}")
print('===' * len(footer))
# Out:
# [02/08/2026] SYSTEM BOOT
# ...
# CLEANING CORRUPTED FILES
# ...
# CLEANING CORRUPTED... [ Consonants         ] -> SUCCESS
# INSTALLING CLEAN CODE... [ Clarified ]
# --------------------------------------------------
# CLEANING CORRUPTED... [ Cognition alignment ] -> SUCCESS
# INSTALLING CLEAN CODE... [ Programming & Natural Language Sync ]
# --------------------------------------------------
# CLEANING CORRUPTED... [ Ticket recovery    ] -> SUCCESS
# INSTALLING CLEAN CODE... [ Refund requested ]
# --------------------------------------------------
# CLEANING CORRUPTED... [ Housing management ] -> SUCCESS
# INSTALLING CLEAN CODE... [ Ultimatum -> [in progress] ]
# --------------------------------------------------
# CLEANING CORRUPTED... [ University network ] -> SUCCESS
# INSTALLING CLEAN CODE... [ Connection established -> [Active] ]
# --------------------------------------------------
#
# Integrity OS: Sovereignty is in progress.
# Architect of Life.
#
# ...
# SYSTEM UPDATED.
# ...

# %% [markdown]
# 2/7/2026
#
# **System Overload**
#
# * CPU hit thermal
# * System crash
# * Cooling CPU
#
# ---
#
# **Syntax**
#
# 1. for key, value: Go through the list 2-by-2.
#
# 2. .items(): Get both the "Title" and the "Description."
#
# 3. :15: Make it look beautiful and aligned

# %%
import time
from datetime import datetime

now = datetime.now()
timestamp = now.strftime('%m/%d%Y')

print(f'{timestamp}\n')

# System error log : February 7, 2026

error_report = {
    'Status': 'System Overload',
    'Hardware_Issue': 'CPU hit thermal limit', # Reached max heat
    'Event': 'Critical System Crash',
    'Action': 'Cooling CPU / Background Task Suspended'
}

print(f'REPORT: {error_report["Status"]}\n' + '-'*30)

for key, value in error_report.items():
    print(f'{key:15}: {value}')
# Out:
# 02/082026
#
# REPORT: System Overload
# ------------------------------
# Status         : System Overload
# Hardware_Issue : CPU hit thermal limit
# Event          : Critical System Crash
# Action         : Cooling CPU / Background Task Suspended

# %% [markdown]
# **2/08/2026**

# %%
import time
from datetime import datetime

now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')

print(f'{timestamp}\n')

# The Data
noise = 'VIRUS-OVERLOAD-DEBT-NOISE'

# The Tool: .strip(), .replace(noise, 'clarity')
clean_frequency = noise.strip().replace(noise, 'clarity')

print(f'Result: {clean_frequency}')
print(f'STATUS: {"SYSTEM STABILIZED"}')
# Out:
# 02/08/2026
#
# Result: clarity
# STATUS: SYSTEM STABILIZED

# %% [markdown]
# 2/9/2026
#
# **time.sleep():**
# * a blocking call
# * 60seconds X 60 minutes = 3600 secs.
# * Do absolutely nothing for exactly one hour.
#
# **sleep command:**
# * Stop consuming: Deep sleep
# * Cooling

# %%
import time
from datetime import datetime

now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')

print(f'{timestamp}\n')

system_is_crash = False

while system_is_crash == True :
    print('Initiating colling cycle...')
    time.sleep(3600) # Stop everything for 1 hour

print(f'CPU clear. System optimized.')
# Out:
# 02/09/2026
#
# CPU clear. System optimized.

# %%
import time
from datetime import datetime

now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')

print(f'{timestamp}\n')

System_Online = True
sleep = True

while System_Online:
    troubles = False
    old_corrupted_files = None
    scheduled = 'System Optimized'

    if sleep == True :
       print('Finalizing Optimization..')
       time.sleep(1) # This is the "Rhythm" or "Breath"
       break

print(f'System Clear')
# Out:
# 02/11/2026
#
# Finalizing Optimization..
# System Clear

# %% [markdown]
# ### **Affordance**
# : A visual or physical clue that tells how an object should be used.
#
# **Type,Definition,Example in your Lab**
# 1. Physical,What the hardware allows.,Your keyboard keys afford pressing.
# 2. Cognitive,Clues that help you understand.,"The word ""Anne:"" tells you it's your turn."
# 3. Functional,What the code actually does.,The input() function affords data entry.
#
# ---
#
# **1. input() and print()**
# * print: computer talking to you.
# * input: computer listening to you.
#
# **2. input string: prompt**
# * inside the parentheses
# * ready for input
# * it prompts you to act
# * visual signal
#
# **3. input blank**
# * always blank with Prompt
#
# **.lower method: Compressor**
# * .lower: change to lowercase

# %%
from datetime import datetime

now = datetime.now()
timestamp = now.strftime('%m/%d/%Y')

print(f'{timestamp}')
header = 'Chat with Python'
print(f'{header}')
print('-' * len(header))

user_input = input("Anne: ")

# We turn your input to lowercase, and we check against a lowercase 'python'
if 'python' in user_input.lower(): # inside change to 'hellow python'
    print('Python: Hi Anne! How are you?')

user_input = input("Anne: ")
if 'snowy' in user_input.lower(): # Inside changed to sad
    print(f"Python: Wow, I love the world when it's covered in white snow.")
# Out:
# 02/20/2026
# Chat with Python
# ----------------
# Anne: Hello Python
# Python: Hi Anne! How are you?
# Anne: I am so excited, it's snowy !!!
# Python: Wow, I love the world when it's covered in white snow.
